# %%
#type_shift = ''
type_shift = '_shift' 

# import build-in
import numpy as np
import os
import random
from shutil import copyfile, copy2 , move, rmtree
from natsort import natsorted
import glob
from tqdm import tqdm

# import local
import utility_classification as ut_cla
import labels_create_ENSO as labels

# %%
path = '/media/nicola/Nicola_data/class/canesm5/regions'+type_shift+'_concat/'

features = ["nino3W.nc","nino3E.nc","nino4W.nc","nino4E.nc","nino12.nc"]
file_id = "r"

dict_data_struc=ut_cla.create_data_struct(path,features,file_id=file_id)
dict_data_struc
# Out:
# {0: {'filename': 'CanESM5_r1i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  1: {'filename': 'CanESM5_r2i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  2: {'filename': 'CanESM5_r3i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  3: {'filename': 'CanESM5_r4i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  4: {'filename': 'CanESM5_r5i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  5: {'filename': 'CanESM5_r6i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  6: {'filename': 'CanESM5_r7i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  7: {'filename': 'CanESM5_r8i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  8: {'filename': 'CanESM5_r9i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  9: {'filename': 'CanESM5_r10i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  10: {'filename': 'CanESM5_r11i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  11: {'filename': 'CanESM5_r12i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  12: {'filename': 'CanESM5_r14i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  13: {'filename': 'CanESM5_r16i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  14: {'filename': 'CanESM5_r17i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  15: {'filename': 'CanESM5_r18i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  16: {'filename': 'CanESM5_r19i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  17: {'filename': 'CanESM5_r20i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  18: {'filename': 'CanESM5_r21i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  19: {'filename': 'CanESM5_r22i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  20: {'filename': 'CanESM5_r23i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  21: {'filename': 'CanESM5_r24i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  22: {'filename': 'CanESM5_r25i1p2f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  23: {'filename': 'CanESM5_r1i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  24: {'filename': 'CanESM5_r2i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  25: {'filename': 'CanESM5_r3i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  26: {'filename': 'CanESM5_r4i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  27: {'filename': 'CanESM5_r5i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  28: {'filename': 'CanESM5_r6i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  29: {'filename': 'CanESM5_r7i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  30: {'filename': 'CanESM5_r8i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  31: {'filename': 'CanESM5_r9i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  32: {'filename': 'CanESM5_r10i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  33: {'filename': 'CanESM5_r11i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  34: {'filename': 'CanESM5_r12i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  35: {'filename': 'CanESM5_r14i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  36: {'filename': 'CanESM5_r16i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  37: {'filename': 'CanESM5_r17i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  38: {'filename': 'CanESM5_r18i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  39: {'filename': 'CanESM5_r19i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  40: {'filename': 'CanESM5_r20i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  41: {'filename': 'CanESM5_r21i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  42: {'filename': 'CanESM5_r22i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  43: {'filename': 'CanESM5_r23i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  44: {'filename': 'CanESM5_r24i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  45: {'filename': 'CanESM5_r25i1p2f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  46: {'filename': 'CanESM5_r1i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  47: {'filename': 'CanESM5_r2i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  48: {'filename': 'CanESM5_r3i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  49: {'filename': 'CanESM5_r4i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  50: {'filename': 'CanESM5_r5i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  51: {'filename': 'CanESM5_r6i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  52: {'filename': 'CanESM5_r7i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  53: {'filename': 'CanESM5_r8i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  54: {'filename': 'CanESM5_r9i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  55: {'filename': 'CanESM5_r10i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  56: {'filename': 'CanESM5_r11i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  57: {'filename': 'CanESM5_r12i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  58: {'filename': 'CanESM5_r14i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  59: {'filename': 'CanESM5_r16i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  60: {'filename': 'CanESM5_r17i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  61: {'filename': 'CanESM5_r18i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  62: {'filename': 'CanESM5_r19i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  63: {'filename': 'CanESM5_r20i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  64: {'filename': 'CanESM5_r21i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  65: {'filename': 'CanESM5_r22i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  66: {'filename': 'CanESM5_r23i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  67: {'filename': 'CanESM5_r24i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  68: {'filename': 'CanESM5_r25i1p2f1.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  69: {'filename': 'CanESM5_r1i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  70: {'filename': 'CanESM5_r2i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  71: {'filename': 'CanESM5_r3i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  72: {'filename': 'CanESM5_r4i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  73: {'filename': 'CanESM5_r5i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  74: {'filename': 'CanESM5_r6i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  75: {'filename': 'CanESM5_r7i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  76: {'filename': 'CanESM5_r8i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  77: {'filename': 'CanESM5_r9i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  78: {'filename': 'CanESM5_r10i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  79: {'filename': 'CanESM5_r11i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  80: {'filename': 'CanESM5_r12i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  81: {'filename': 'CanESM5_r14i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  82: {'filename': 'CanESM5_r16i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  83: {'filename': 'CanESM5_r17i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  84: {'filename': 'CanESM5_r18i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  85: {'filename': 'CanESM5_r19i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  86: {'filename': 'CanESM5_r20i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  87: {'filename': 'CanESM5_r21i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  88: {'filename': 'CanESM5_r22i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  89: {'filename': 'CanESM5_r23i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  90: {'filename': 'CanESM5_r24i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  91: {'filename': 'CanESM5_r25i1p2f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  92: {'filename': 'CanESM5_r1i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  93: {'filename': 'CanESM5_r2i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  94: {'filename': 'CanESM5_r3i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  95: {'filename': 'CanESM5_r4i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  96: {'filename': 'CanESM5_r5i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  97: {'filename': 'CanESM5_r6i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  98: {'filename': 'CanESM5_r7i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  99: {'filename': 'CanESM5_r8i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  100: {'filename': 'CanESM5_r9i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  101: {'filename': 'CanESM5_r10i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  102: {'filename': 'CanESM5_r11i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  103: {'filename': 'CanESM5_r12i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  104: {'filename': 'CanESM5_r14i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  105: {'filename': 'CanESM5_r16i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  106: {'filename': 'CanESM5_r17i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  107: {'filename': 'CanESM5_r18i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  108: {'filename': 'CanESM5_r19i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  109: {'filename': 'CanESM5_r20i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  110: {'filename': 'CanESM5_r21i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  111: {'filename': 'CanESM5_r22i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  112: {'filename': 'CanESM5_r23i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  113: {'filename': 'CanESM5_r24i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  114: {'filename': 'CanESM5_r25i1p2f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6}}

# %%
#process all data
result = ut_cla.preprocess_from_dict2(dict_data_struc, path, verbose=False)

# %%
# Concatenate 
def concat_features(result, keys, axis=0):
    list_= [result[key] for key in keys]
    return np.concatenate(list_,axis=axis)
    
keys=list(range(0,23)) # key to concatenate
concat_N3W= concat_features(result, keys)

keys=list(range(23,46)) # key to concatenate
concat_N3E= concat_features(result, keys)

keys=list(range(46,69)) # key to concatenate
concat_N4W= concat_features(result, keys)

keys=list(range(69,92)) # key to concatenate
concat_N4E= concat_features(result, keys)

keys=list(range(92,115)) # key to concatenate
concat_N12= concat_features(result, keys)
##

input_train=np.concatenate([concat_N3W,concat_N3E,concat_N4W,concat_N4E,concat_N12],axis=1)

# %%
import joblib

filename = 'ensemble_classifier_final.sav'
clf =joblib.load(filename)

prediction2=clf.predict(input_train)

with open('classified_model_output/canesm5'+type_shift+'.txt', 'w') as filehandle:  
    for listitem in prediction2:
        filehandle.write('%s\n' % listitem)
