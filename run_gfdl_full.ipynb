# %%
#type_shift = ''
type_shift = '_shift' 

# import build-in
import numpy as np

# import local
import utility_classification as ut_cla
import labels_create_ENSO as labels

# %%
path = '/media/nicola/Nicola_data/class/gfdl_esm2m/regions'+type_shift+'/'

features = ["nino3W.nc","nino3E.nc","nino4W.nc","nino4E.nc","nino12.nc"]
file_id = "ens"

dict_data_struc=ut_cla.create_data_struct(path,features,file_id=file_id)
dict_data_struc
# Out:
# {0: {'filename': 'sst_ens101_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  1: {'filename': 'sst_ens102_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  2: {'filename': 'sst_ens103_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  3: {'filename': 'sst_ens104_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  4: {'filename': 'sst_ens105_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  5: {'filename': 'sst_ens106_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  6: {'filename': 'sst_ens107_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  7: {'filename': 'sst_ens108_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  8: {'filename': 'sst_ens109_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  9: {'filename': 'sst_ens110_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  10: {'filename': 'sst_ens111_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  11: {'filename': 'sst_ens112_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  12: {'filename': 'sst_ens113_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  13: {'filename': 'sst_ens114_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  14: {'filename': 'sst_ens115_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  15: {'filename': 'sst_ens116_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  16: {'filename': 'sst_ens117_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  17: {'filename': 'sst_ens118_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  18: {'filename': 'sst_ens119_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  19: {'filename': 'sst_ens120_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  20: {'filename': 'sst_ens121_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  21: {'filename': 'sst_ens122_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  22: {'filename': 'sst_ens123_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  23: {'filename': 'sst_ens124_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  24: {'filename': 'sst_ens125_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  25: {'filename': 'sst_ens126_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  26: {'filename': 'sst_ens127_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  27: {'filename': 'sst_ens128_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  28: {'filename': 'sst_ens129_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  29: {'filename': 'sst_ens130_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  30: {'filename': 'sst_ens101_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  31: {'filename': 'sst_ens102_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  32: {'filename': 'sst_ens103_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  33: {'filename': 'sst_ens104_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  34: {'filename': 'sst_ens105_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  35: {'filename': 'sst_ens106_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  36: {'filename': 'sst_ens107_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  37: {'filename': 'sst_ens108_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  38: {'filename': 'sst_ens109_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  39: {'filename': 'sst_ens110_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  40: {'filename': 'sst_ens111_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  41: {'filename': 'sst_ens112_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  42: {'filename': 'sst_ens113_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  43: {'filename': 'sst_ens114_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  44: {'filename': 'sst_ens115_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  45: {'filename': 'sst_ens116_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  46: {'filename': 'sst_ens117_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  47: {'filename': 'sst_ens118_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  48: {'filename': 'sst_ens119_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  49: {'filename': 'sst_ens120_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  50: {'filename': 'sst_ens121_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  51: {'filename': 'sst_ens122_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  52: {'filename': 'sst_ens123_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  53: {'filename': 'sst_ens124_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  54: {'filename': 'sst_ens125_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  55: {'filename': 'sst_ens126_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  56: {'filename': 'sst_ens127_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  57: {'filename': 'sst_ens128_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  58: {'filename': 'sst_ens129_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  59: {'filename': 'sst_ens130_1x1_1950_2100.nc_remap.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  60: {'filename': 'sst_ens101_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  61: {'filename': 'sst_ens102_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  62: {'filename': 'sst_ens103_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  63: {'filename': 'sst_ens104_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  64: {'filename': 'sst_ens105_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  65: {'filename': 'sst_ens106_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  66: {'filename': 'sst_ens107_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  67: {'filename': 'sst_ens108_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  68: {'filename': 'sst_ens109_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  69: {'filename': 'sst_ens110_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  70: {'filename': 'sst_ens111_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  71: {'filename': 'sst_ens112_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  72: {'filename': 'sst_ens113_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  73: {'filename': 'sst_ens114_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  74: {'filename': 'sst_ens115_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  75: {'filename': 'sst_ens116_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  76: {'filename': 'sst_ens117_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  77: {'filename': 'sst_ens118_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  78: {'filename': 'sst_ens119_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  79: {'filename': 'sst_ens120_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  80: {'filename': 'sst_ens121_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  81: {'filename': 'sst_ens122_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  82: {'filename': 'sst_ens123_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  83: {'filename': 'sst_ens124_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  84: {'filename': 'sst_ens125_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  85: {'filename': 'sst_ens126_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  86: {'filename': 'sst_ens127_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  87: {'filename': 'sst_ens128_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  88: {'filename': 'sst_ens129_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  89: {'filename': 'sst_ens130_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  90: {'filename': 'sst_ens101_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  91: {'filename': 'sst_ens102_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  92: {'filename': 'sst_ens103_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  93: {'filename': 'sst_ens104_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  94: {'filename': 'sst_ens105_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  95: {'filename': 'sst_ens106_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  96: {'filename': 'sst_ens107_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  97: {'filename': 'sst_ens108_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  98: {'filename': 'sst_ens109_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  99: {'filename': 'sst_ens110_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  100: {'filename': 'sst_ens111_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  101: {'filename': 'sst_ens112_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  102: {'filename': 'sst_ens113_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  103: {'filename': 'sst_ens114_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  104: {'filename': 'sst_ens115_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  105: {'filename': 'sst_ens116_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  106: {'filename': 'sst_ens117_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  107: {'filename': 'sst_ens118_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  108: {'filename': 'sst_ens119_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  109: {'filename': 'sst_ens120_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  110: {'filename': 'sst_ens121_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  111: {'filename': 'sst_ens122_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  112: {'filename': 'sst_ens123_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  113: {'filename': 'sst_ens124_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  114: {'filename': 'sst_ens125_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  115: {'filename': 'sst_ens126_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  116: {'filename': 'sst_ens127_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  117: {'filename': 'sst_ens128_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  118: {'filename': 'sst_ens129_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  119: {'filename': 'sst_ens130_1x1_1950_2100.nc_remap.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  120: {'filename': 'sst_ens101_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  121: {'filename': 'sst_ens102_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  122: {'filename': 'sst_ens103_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  123: {'filename': 'sst_ens104_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  124: {'filename': 'sst_ens105_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  125: {'filename': 'sst_ens106_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  126: {'filename': 'sst_ens107_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  127: {'filename': 'sst_ens108_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  128: {'filename': 'sst_ens109_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  129: {'filename': 'sst_ens110_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  130: {'filename': 'sst_ens111_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  131: {'filename': 'sst_ens112_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  132: {'filename': 'sst_ens113_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  133: {'filename': 'sst_ens114_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  134: {'filename': 'sst_ens115_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  135: {'filename': 'sst_ens116_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  136: {'filename': 'sst_ens117_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  137: {'filename': 'sst_ens118_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  138: {'filename': 'sst_ens119_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  139: {'filename': 'sst_ens120_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  140: {'filename': 'sst_ens121_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  141: {'filename': 'sst_ens122_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  142: {'filename': 'sst_ens123_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  143: {'filename': 'sst_ens124_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  144: {'filename': 'sst_ens125_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  145: {'filename': 'sst_ens126_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  146: {'filename': 'sst_ens127_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  147: {'filename': 'sst_ens128_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  148: {'filename': 'sst_ens129_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  149: {'filename': 'sst_ens130_1x1_1950_2100.nc_remap.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6}}

# %%
#process all data
result = ut_cla.preprocess_from_dict2(dict_data_struc, path, verbose=False)

# %%
# Concatenate 
def concat_features(result, keys, axis=0):
    list_= [result[key] for key in keys]
    return np.concatenate(list_,axis=axis)
    
keys=list(range(0,30)) # key to concatenate
concat_N3W= concat_features(result, keys)

keys=list(range(30,60)) # key to concatenate
concat_N3E= concat_features(result, keys)

keys=list(range(60,90)) # key to concatenate
concat_N4W= concat_features(result, keys)

keys=list(range(90,120)) # key to concatenate
concat_N4E= concat_features(result, keys)

keys=list(range(120,150)) # key to concatenate
concat_N12= concat_features(result, keys)
##

input_train=np.concatenate([concat_N3W,concat_N3E,concat_N4W,concat_N4E,concat_N12],axis=1)

# %%
import joblib

filename = 'ensemble_classifier_final.sav'
clf =joblib.load(filename)

prediction2=clf.predict(input_train)

with open('classified_model_output/gfdl'+type_shift+'.txt', 'w') as filehandle:  
    for listitem in prediction2:
        filehandle.write('%s\n' % listitem)
