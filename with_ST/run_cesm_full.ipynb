# %%
type_shift = ''
#type_shift = '_shift' 

# import build-in
import numpy as np
import os
import random
from shutil import copyfile, copy2 , move, rmtree
from natsort import natsorted
import glob
from tqdm import tqdm

# import local
import utility_classification as ut_cla
import labels_create_ENSO_ST as labels

# %%
path = '/media/nicola/Nicola_data/class/cesm/regions'+type_shift+'/'

features = ["nino3W.nc","nino3E.nc","nino4W.nc","nino4E.nc","nino12.nc"]
file_id = "tos"

dict_data_struc=ut_cla.create_data_struct(path,features,file_id=file_id)
dict_data_struc
# Out:
# {0: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r1i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  1: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r2i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  2: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r3i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  3: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r4i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  4: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r5i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  5: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r6i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  6: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r7i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  7: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r8i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  8: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r9i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  9: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r10i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  10: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r11i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  11: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r12i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  12: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r13i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  13: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r14i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  14: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r15i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  15: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r16i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  16: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r17i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  17: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r18i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  18: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r19i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  19: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r20i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  20: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r21i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  21: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r22i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  22: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r23i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  23: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r24i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  24: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r25i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  25: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r26i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  26: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r27i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  27: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r28i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  28: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r29i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  29: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r30i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  30: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r31i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  31: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r32i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  32: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r33i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  33: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r34i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  34: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r35i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  35: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r36i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  36: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r37i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  37: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r38i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  38: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r39i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  39: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r40i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  40: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r1i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  41: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r2i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  42: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r3i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  43: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r4i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  44: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r5i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  45: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r6i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  46: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r7i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  47: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r8i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  48: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r9i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  49: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r10i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  50: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r11i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  51: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r12i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  52: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r13i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  53: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r14i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  54: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r15i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  55: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r16i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  56: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r17i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  57: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r18i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  58: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r19i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  59: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r20i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  60: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r21i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  61: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r22i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  62: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r23i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  63: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r24i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  64: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r25i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  65: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r26i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  66: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r27i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  67: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r28i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  68: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r29i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  69: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r30i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  70: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r31i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  71: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r32i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  72: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r33i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  73: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r34i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  74: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r35i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  75: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r36i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  76: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r37i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  77: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r38i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  78: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r39i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  79: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r40i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  80: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r1i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  81: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r2i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  82: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r3i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  83: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r4i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  84: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r5i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  85: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r6i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  86: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r7i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  87: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r8i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  88: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r9i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  89: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r10i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  90: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r11i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  91: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r12i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  92: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r13i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  93: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r14i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  94: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r15i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  95: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r16i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  96: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r17i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  97: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r18i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  98: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r19i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  99: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r20i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  100: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r21i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  101: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r22i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  102: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r23i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  103: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r24i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  104: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r25i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  105: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r26i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  106: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r27i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  107: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r28i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  108: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r29i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  109: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r30i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  110: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r31i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  111: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r32i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  112: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r33i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  113: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r34i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  114: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r35i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  115: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r36i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  116: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r37i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  117: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r38i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  118: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r39i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  119: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r40i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4W.nc',
#   'crop': 0,
#   'firstmon': 10},
#  120: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r1i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  121: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r2i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  122: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r3i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  123: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r4i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  124: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r5i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  125: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r6i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  126: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r7i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  127: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r8i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  128: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r9i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  129: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r10i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  130: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r11i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  131: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r12i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  132: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r13i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  133: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r14i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  134: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r15i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  135: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r16i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  136: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r17i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  137: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r18i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  138: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r19i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  139: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r20i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  140: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r21i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  141: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r22i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  142: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r23i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  143: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r24i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  144: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r25i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  145: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r26i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  146: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r27i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  147: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r28i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  148: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r29i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  149: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r30i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  150: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r31i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  151: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r32i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  152: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r33i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  153: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r34i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  154: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r35i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  155: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r36i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  156: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r37i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  157: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r38i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  158: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r39i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  159: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r40i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 10},
#  160: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r1i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  161: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r2i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  162: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r3i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  163: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r4i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  164: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r5i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  165: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r6i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  166: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r7i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  167: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r8i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  168: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r9i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  169: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r10i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  170: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r11i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  171: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r12i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  172: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r13i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  173: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r14i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  174: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r15i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  175: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r16i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  176: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r17i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  177: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r18i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  178: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r19i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  179: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r20i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  180: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r21i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  181: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r22i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  182: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r23i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  183: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r24i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  184: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r25i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  185: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r26i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  186: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r27i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  187: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r28i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  188: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r29i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  189: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r30i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  190: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r31i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  191: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r32i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  192: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r33i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  193: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r34i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  194: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r35i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  195: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r36i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  196: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r37i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  197: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r38i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  198: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r39i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10},
#  199: {'filename': 'tos_Omon_CESM1-CAM5_historical_rcp85_r40i1p1_192001-210012.nc_fix.nc_remap.nc_region.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 10}}

# %%
#process all data
result = ut_cla.preprocess_from_dict(dict_data_struc, path, verbose=False)

# %%
# Concatenate 
def concat_features(result, keys, axis=0):
    list_= [result[key] for key in keys]
    return np.concatenate(list_,axis=axis)
    
keys=list(range(0,40)) # key to concatenate
concat_N3W= concat_features(result, keys)

keys=list(range(40,80)) # key to concatenate
concat_N3E= concat_features(result, keys)

keys=list(range(80,120)) # key to concatenate
concat_N4W= concat_features(result, keys)

keys=list(range(120,160)) # key to concatenate
concat_N4E= concat_features(result, keys)

keys=list(range(160,200)) # key to concatenate
concat_N12= concat_features(result, keys)
##

input_train=np.concatenate([concat_N3W,concat_N3E,concat_N4W,concat_N4E,concat_N12],axis=1)

# %%
import joblib

filename = 'ensemble_classifier_final.sav'
clf =joblib.load(filename)

prediction2=clf.predict(input_train)

with open('classified_model_output/cesm'+type_shift+'.txt', 'w') as filehandle:  
    for listitem in prediction2:
        filehandle.write('%s\n' % listitem)
