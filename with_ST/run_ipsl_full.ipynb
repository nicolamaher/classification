# %%
type_shift = ''
#type_shift = '_shift' 

# import build-in
import numpy as np
import os
import random
from shutil import copyfile, copy2 , move, rmtree
from natsort import natsorted
import glob
from tqdm import tqdm

# import local
import utility_classification as ut_cla
import labels_create_ENSO_ST as labels

# %%
path = '/media/nicola/Nicola_data/class/ipsl/regions'+type_shift+'/'

features = ["nino3W.nc","nino3E.nc","nino4W.nc","nino4E.nc","nino12.nc"]
file_id = "LE"

dict_data_struc=ut_cla.create_data_struct(path,features,file_id=file_id)
dict_data_struc
# Out:
# {0: {'filename': 'IPSL-CM6A-LE_r1i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  1: {'filename': 'IPSL-CM6A-LE_r2i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  2: {'filename': 'IPSL-CM6A-LE_r3i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  3: {'filename': 'IPSL-CM6A-LE_r4i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  4: {'filename': 'IPSL-CM6A-LE_r5i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  5: {'filename': 'IPSL-CM6A-LE_r6i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  6: {'filename': 'IPSL-CM6A-LE_r7i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  7: {'filename': 'IPSL-CM6A-LE_r8i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  8: {'filename': 'IPSL-CM6A-LE_r9i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  9: {'filename': 'IPSL-CM6A-LE_r10i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  10: {'filename': 'IPSL-CM6A-LE_r11i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  11: {'filename': 'IPSL-CM6A-LE_r12i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  12: {'filename': 'IPSL-CM6A-LE_r13i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  13: {'filename': 'IPSL-CM6A-LE_r14i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  14: {'filename': 'IPSL-CM6A-LE_r15i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  15: {'filename': 'IPSL-CM6A-LE_r16i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  16: {'filename': 'IPSL-CM6A-LE_r17i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  17: {'filename': 'IPSL-CM6A-LE_r18i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  18: {'filename': 'IPSL-CM6A-LE_r19i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  19: {'filename': 'IPSL-CM6A-LE_r20i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  20: {'filename': 'IPSL-CM6A-LE_r21i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  21: {'filename': 'IPSL-CM6A-LE_r22i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  22: {'filename': 'IPSL-CM6A-LE_r23i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  23: {'filename': 'IPSL-CM6A-LE_r24i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  24: {'filename': 'IPSL-CM6A-LE_r25i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  25: {'filename': 'IPSL-CM6A-LE_r26i1p1f1.nc_detrend.nc_nino3W.nc',
#   'crop': 0,
#   'firstmon': 6},
#  26: {'filename': 'IPSL-CM6A-LE_r1i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  27: {'filename': 'IPSL-CM6A-LE_r2i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  28: {'filename': 'IPSL-CM6A-LE_r3i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  29: {'filename': 'IPSL-CM6A-LE_r4i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  30: {'filename': 'IPSL-CM6A-LE_r5i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  31: {'filename': 'IPSL-CM6A-LE_r6i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  32: {'filename': 'IPSL-CM6A-LE_r7i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  33: {'filename': 'IPSL-CM6A-LE_r8i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  34: {'filename': 'IPSL-CM6A-LE_r9i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  35: {'filename': 'IPSL-CM6A-LE_r10i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  36: {'filename': 'IPSL-CM6A-LE_r11i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  37: {'filename': 'IPSL-CM6A-LE_r12i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  38: {'filename': 'IPSL-CM6A-LE_r13i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  39: {'filename': 'IPSL-CM6A-LE_r14i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  40: {'filename': 'IPSL-CM6A-LE_r15i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  41: {'filename': 'IPSL-CM6A-LE_r16i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  42: {'filename': 'IPSL-CM6A-LE_r17i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  43: {'filename': 'IPSL-CM6A-LE_r18i1p1f1.nc_detrend.nc_nino3E.nc',
#   'crop': 0,
#   'firstmon': 6},
#
1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  97: {'filename': 'IPSL-CM6A-LE_r20i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  98: {'filename': 'IPSL-CM6A-LE_r21i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  99: {'filename': 'IPSL-CM6A-LE_r22i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  100: {'filename': 'IPSL-CM6A-LE_r23i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  101: {'filename': 'IPSL-CM6A-LE_r24i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  102: {'filename': 'IPSL-CM6A-LE_r25i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  103: {'filename': 'IPSL-CM6A-LE_r26i1p1f1.nc_detrend.nc_nino4E.nc',
#   'crop': 0,
#   'firstmon': 6},
#  104: {'filename': 'IPSL-CM6A-LE_r1i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  105: {'filename': 'IPSL-CM6A-LE_r2i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  106: {'filename': 'IPSL-CM6A-LE_r3i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  107: {'filename': 'IPSL-CM6A-LE_r4i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  108: {'filename': 'IPSL-CM6A-LE_r5i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  109: {'filename': 'IPSL-CM6A-LE_r6i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  110: {'filename': 'IPSL-CM6A-LE_r7i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  111: {'filename': 'IPSL-CM6A-LE_r8i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  112: {'filename': 'IPSL-CM6A-LE_r9i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  113: {'filename': 'IPSL-CM6A-LE_r10i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  114: {'filename': 'IPSL-CM6A-LE_r11i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  115: {'filename': 'IPSL-CM6A-LE_r12i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  116: {'filename': 'IPSL-CM6A-LE_r13i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  117: {'filename': 'IPSL-CM6A-LE_r14i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  118: {'filename': 'IPSL-CM6A-LE_r15i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  119: {'filename': 'IPSL-CM6A-LE_r16i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  120: {'filename': 'IPSL-CM6A-LE_r17i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  121: {'filename': 'IPSL-CM6A-LE_r18i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  122: {'filename': 'IPSL-CM6A-LE_r19i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  123: {'filename': 'IPSL-CM6A-LE_r20i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  124: {'filename': 'IPSL-CM6A-LE_r21i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  125: {'filename': 'IPSL-CM6A-LE_r22i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  126: {'filename': 'IPSL-CM6A-LE_r23i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  127: {'filename': 'IPSL-CM6A-LE_r24i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  128: {'filename': 'IPSL-CM6A-LE_r25i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6},
#  129: {'filename': 'IPSL-CM6A-LE_r26i1p1f1.nc_detrend.nc_nino12.nc',
#   'crop': 0,
#   'firstmon': 6}}

# %%
#process all data
result = ut_cla.preprocess_from_dict2(dict_data_struc, path, verbose=False)

# %%
# Concatenate 
def concat_features(result, keys, axis=0):
    list_= [result[key] for key in keys]
    return np.concatenate(list_,axis=axis)
    
keys=list(range(0,26)) # key to concatenate
concat_N3W= concat_features(result, keys)

keys=list(range(26,52)) # key to concatenate
concat_N3E= concat_features(result, keys)

keys=list(range(52,78)) # key to concatenate
concat_N4W= concat_features(result, keys)

keys=list(range(78,104)) # key to concatenate
concat_N4E= concat_features(result, keys)

keys=list(range(104,130)) # key to concatenate
concat_N12= concat_features(result, keys)
##

input_train=np.concatenate([concat_N3W,concat_N3E,concat_N4W,concat_N4E,concat_N12],axis=1)

# %%
import joblib

filename = 'ensemble_classifier_final.sav'
clf =joblib.load(filename)

prediction2=clf.predict(input_train)

with open('classified_model_output/ipsl'+type_shift+'.txt', 'w') as filehandle:  
    for listitem in prediction2:
        filehandle.write('%s\n' % listitem)
